# %% [markdown]
# pandas 라이브러리 호출

# %%
import pandas as pd     # pandas 라이브러리를 pd 이름으로 호출

# %%
dates = pd.date_range('20181201', periods=4)     # date_range 함수를 이용해 날짜 생성
dates

# %%
prices = {'A전자' : [1000, 1010, 1020, 1030],
          'B화학' : [2000, 2010, 2020, 2030],
          'C금융' : [3000, 3010, 3020, 3030]}
df = pd.DataFrame(prices, index=dates)
df

# %% [markdown]
# B화학의 12월2일 주가를 뽑으세요

# %%
df.loc['2018-12-02', 'B화학']

# %% [markdown]
# C금융의 12월2일 이후 주가를 뽑으세요

# %%
df.loc['2018-12-02':, 'C금융']

# %% [markdown]
# 12월4일 주가에 10원씩 더해서 12월5일 데이터를 추가해보세요

# %%
df.loc['2018-12-04'] + 10

# %%
df.loc[pd.to_datetime('2018-12-05')] = df.loc['2018-12-04'] + 10
df

# %%
type(df.index)

# %% [markdown]
# cf. 날짜타입을 명시하지 않고 데이터를 추가하는 경우

# %%
df.loc['2018-12-06'] = df.loc['2018-12-04'] + 10
df

# %%
type(df.index)
